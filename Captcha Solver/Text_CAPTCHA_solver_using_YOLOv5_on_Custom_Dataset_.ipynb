# %% [markdown]
# Based on this tutorial [Train Your Own YoloV5 Object Detection Model | analyticsvidhya.com](https://www.analyticsvidhya.com/blog/2021/08/train-your-own-yolov5-object-detection-model/#h2_3)

# %% [markdown]
# ## Creating Dataset

# %% [markdown]
# ### Create annotations Using the VIA tool
# Create annotations by using [this VIA (VGG Image Annotator) tool](https://drive.google.com/file/d/1rJx0fNgnnhODM7H3GP9RQQ5QEsWdkYEd/view?usp=sharing)
#
# using tool:
# first create attribute named char
# upload files
# create annotations
# and export annotations by clicking menu > annotations > export annotations as CSV

# %% [markdown]
# ### Convert CSV annotations to COCO format
#
# To convert CSV annotations to COCO format you can use the following code chunk:
#
# Start with importing dependencies to create COCO dataset.

# %%
import os
import numpy as np 
import pandas as pd
import shutil as sh
from PIL import Image
from tqdm.auto import tqdm
from pathlib import Path

# %%
# !mkdir '/content/images/'
# !mkdir '/content/images/train'

# %% [markdown]
# upload annotation .csv
#  files to above second  path

# %% [markdown]
# Upload images zip file on main path

# %%
# !unzip -qq '/content/first_250_dataset.zip'
# !cd '/content/first_250_dataset/' && cp -r * '/content/images/'

# %%
data_path = '/content/images/'
df = pd.read_csv(data_path+'train/csv250_1.csv')
## create x, y, w, h columns 
x, y, w, h = [], [], [], []
count = 0
for row in df['region_shape_attributes']:
    count = count + 1
    row = row.replace('{}', '').replace('}', '')
    row = row.split(',')
    x.append(int(row[1].split(':')[-1]))
    y.append(int(row[2].split(':')[-1]))
    w.append(int(row[3].split(':')[-1]))
    h.append(int(row[4].split(':')[-1]))
## calculating x, y, width and height coordinates
df['x'], df['y'], df['w'], df['h'] = x, y, w, h
## creating a column name image_id having images names as id 
df['image_id'] = [name.split('.')[0] for name in df['filename']]
## creating two columns for storing x and y center values
df['x_center'] = df['x'] + df['w']/2
df['y_center'] = df['y'] + df['h']/2
## define number of classes 
labels = df['region_attributes'].unique()
labels_to_dict = dict(zip(labels, range(0, len(labels))))
print('Lables Directory:', labels_to_dict)
df['classes'] = df['region_attributes']
df.replace({'classes':labels_to_dict}, inplace=True)
df = df[['image_id','x', 'y', 'w', 'h','x_center','y_center','classes']]
## set index of images
index = list(set(df.image_id))
# Out:
# Lables Directory: {'{"char":"2"}': 0, '{"char":"A"}': 1, '{"char":"H"}': 2, '{"char":"N"}': 3, '{"char":"3"}': 4, '{"char":"L"}': 5, '{"char":"S"}': 6, '{"char":"G"}': 7, '{"char":"P"}': 8, '{"char":"6"}': 9, '{"char":"T"}': 10, '{"char":"J"}': 11, '{"char":"F"}': 12, '{"char":"R"}': 13, '{"char":"Q"}': 14, '{"char":"D"}': 15, '{"char":"5"}': 16, '{"char":"B"}': 17, '{"char":"7"}': 18, '{"char":"8"}': 19, '{"char":"E"}': 20, '{"char":"9"}': 21, '{"char":"Y"}': 22, '{"char":"4"}': 23, '{"char":"W"}': 24, '{"char":"K"}': 25, '{"char":"U"}': 26, '{"char":"X"}': 27, '{"char":"V"}': 28, '{"char":"C"}': 29, '{"char":"M"}': 30, '{"char":" Q"}': 31}

# %%
if True:
    for fold in [0]:
        val_index = index[len(index) * fold // 5 : len(index) * (fold + 1) // 5]
        for name, mini in tqdm(df.groupby("image_id")):
            if name in val_index:
                path2save = "val2017/"
            else:
                path2save = "train2017/"
            if not os.path.exists("convertor/fold{}/labels/".format(fold) + path2save):
                os.makedirs("convertor/fold{}/labels/".format(fold) + path2save)
            with open(
                "convertor/fold{}/labels/".format(fold) + path2save + name + ".txt",
                "w+",
            ) as f:
                row = (
                    mini[["classes", "x_center", "y_center", "w", "h"]]
                    .astype(float)
                    .values
                )
                imagename = data_path + "{}.png".format(name)
                ext = ["png", "JPG", "PNG", "jpg"]
                for ext_ in ext:
                    imagename = data_path + "{}.{}".format(name, ext_)
                    if os.path.exists(imagename):
                        break
                check_image_width_height = Image.open(imagename)
                img_width, img_height = check_image_width_height.size
                for r in row:
                    r[1] = r[1] / img_width
                    r[2] = r[2] / img_height
                    r[3] = r[3] / img_width
                    r[4] = r[4] / img_height
                row = row.astype(str)
                for j in range(len(row)):
                    # print(row[j], "n")
                    row[j][0] = str(int(float(row[j][0])))
                    text = " ".join(row[j])
                    f.write(text)
                    f.write("\n")
            if not os.path.exists("convertor/fold{}/images/{}".format(fold, path2save)):
                os.makedirs("convertor/fold{}/images/{}".format(fold, path2save))
            sh.copy(
                imagename,
                "convertor/fold{}/images/{}/{}.{}".format(fold, path2save, name, ext_),
            )
# Out:
#   0%|          | 0/250 [00:00<?, ?it/s]

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 11142, done.
# remote: Total 11142 (delta 0), reused 0 (delta 0), pack-reused 11142
# Receiving objects: 100% (11142/11142), 11.14 MiB | 33.74 MiB/s, done.
# Resolving deltas: 100% (7703/7703), done.

# %%
# %cd '/content/yolov5'
# Out:
# /content/yolov5

# %%
# Path to the data directory
# data_dir = Path("/content/temp")    # for 4k dataset
data_dir = Path("/content/images")   # for 11k dataset


# Get list of all the images
images = sorted(list(map(str, list(data_dir.glob("*.png")))))
labels = [img.split(os.path.sep)[-1].split(".png")[0] for img in images]
characters = set(char for label in labels for char in label)
all_characters = list(char for label in labels for char in label)

print("Number of images found: ", len(images))
print("Number of labels found: ", len(labels))
print("Number of unique characters: ", len(characters))
print("Characters present: ", sorted(characters))

# Batch size for training and validation
batch_size = 450

# Desired image dimensions
img_width = 300
img_height = 90

# Factor by which the image is going to be downsampled
# by the convolutional blocks. We will be using two
# convolution blocks and each block will have
# a pooling layer which downsample the features by a factor of 2.
# Hence total downsampling factor would be 4.
downsample_factor = 4

# Maximum length of any captcha in the dataset
max_length = max([len(label) for label in labels])
# Out:
# Number of images found:  236
# Number of labels found:  236
# Number of unique characters:  31
# Characters present:  ['2', '3', '4', '5', '6', '7', '8', '9', 'A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'J', 'K', 'L', 'M', 'N', 'P', 'Q', 'R', 'S', 'T', 'U', 'V', 'W', 'X', 'Y']

# %% [markdown]
# ### Creating YAML file for training

# %%
# train and val data as 1) directory: path/images/, 2) file: path/images.txt, or 3) list: [path1/images/, path2/images/]

# %%
# %%writefile data/coco.yml
# train: /content/convertor/fold0/images/train2017
# val: /content/convertor/fold0/images/val2017
# nc: 32 # number of classes
# names: [2,A,H,N,3,L,S,G,P,6,T,J,F,R,Q,D,5,B,7,8,E,9,Y,4,W,K,U,X,V,C,M,Q]   # sorting should be accoring to Lables Directory: in preprocessing part

# %% [markdown]
# ## Training

# %%
# !python train.py --batch 12 --epochs 50 --data ./data/coco.yml --weights ./weights/yolov5x.pt  #./runs/train/exp2/weights/best.pt
# Out:
# train: weights=./weights/yolov5x.pt, cfg=, data=./data/coco.yml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=50, batch_size=12, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.1-11-g63ddb6f torch 1.10.0+cu111 CUDA:0 (Tesla T4, 15110MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# Weights & Biases: run 'pip install wandb' to automatically track and visualize YOLOv5 🚀 runs (RECOMMENDED)
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# Downloading https://github.com/ultralytics/yolov5/releases/download/v6.1/yolov5x.pt to weights/yolov5x.pt...
# 100% 166M/166M [00:01<00:00, 108MB/s]
#
# Overriding model.yaml nc=80 with nc=32
#
#                  from  n    params  module                                  arguments
#   0                -1  1      8800  models.common.Conv                      [3, 80, 6, 2, 2]
#   1                -1  1    115520  models.common.Conv                      [80, 160, 3, 2]
#   2                -1  4    309120  models.common.C3                        [160, 160, 4]
#   3                -1  1    461440  models.common.Conv                      [160, 320, 3, 2]
#   4                -1  8   2259200  models.common.C3                        [320, 320, 8]
#   5                -1  1   1844480  models.common.Conv                      [320, 640, 3, 2]
#   6                -1 12  13125120  models.common.C3                        [640, 640, 12]
#   7                -1  1   7375360  models.common.Conv                      [640, 1280, 3, 2]
#   8                -1  4  19676160  models.common.C3                        [1280, 1280, 4]
#   9                -1  1   4099840  models.common.SPPF                      [1280, 1280, 5]
#  10                -1  1    820480  models.common.Conv                      [1280, 640, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  4   5332480  models.common.C3                        [1280, 640, 4, False]
#  14                -1  1    205440  models.common.Conv                      [640, 320, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  4   1335040  models.common.C3                        [640, 320, 4, False]
#  18                -1  1    922240  models.common.Conv                      [320, 320, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  4   4922880  models.common.C3                        [640, 640, 4, False]
#  21                -1  1   3687680  models.common.Conv                      [640, 640, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  4  19676160  models.common.C3                        [1280, 1280, 4, False]
#  24      [17, 20, 23]  1    248973  models.yolo.Detect                      [32, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [320, 640, 1280]]
# Model Summary: 567 layers, 86426413 parameters, 86426413 gradients
#
# Transferred 739/745 items from weights/yolov5x.pt
# Scaled weight_decay = 0.00046875
# optimizer: SGD with parameter groups 123 weight (no decay), 126 weight, 126 bias
# albumentations: version 1.0.3 required by YOLOv5, but version 0.1.12 is currently installed
# train: Scanning '/content/convertor/fold0/labels/train2017.cache' images and labels... 200 found, 0 missing, 0 empty, 0 corrupt: 100% 200/200 [00:00<?, ?it/s]
# val: Scanning '/content/convertor/fold0/labels/val2017.cache' images and labels... 50 found, 0 missing, 0 empty, 0 corrupt: 100% 50/50 [00:00<?, ?it/s]
# Plotting labels to runs/train/exp3/labels.jpg...
#
# AutoAnchor: 6.43 anchors/target, 1.000 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to runs/train/exp3
# Starting training for 50 epochs...
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       0/49     11.1G    0.1089   0.09564   0.08806       143       640: 100% 17/17 [00:17<00:00,  1.05s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 3/3 [00:00<00:00,  4.88it/s]
#                  all         50        300    0.00851     0.0577     0.0101    0.00211
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       1/49     11.1G   0.08477    0.1002    0.0865       100       640: 100% 17/17 [00:13<00:00,  1.22it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 3/3 [00:01<00:00,  1.69it/s]
#                  all         50        300      0.177      0.228     0.0411     0.0115
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       2/49     11.1G    0.0892   0.07845   0.08381        96       640: 100% 17/17 [00:13<00:00,  1.22it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 3/3 [00:01<00:00,  2.06it/s]
#                  all         50        300    0.00421      0.187    0.00736    0.00111
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       3/49     11.1G   0.09372    0.0665   0.08173        87       640: 100% 17/17 [00:14<00:00,  1.21it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 3/3 [00:00<00:00,  3.94it/s]
#                  all         50        300       0.33     0.0376    0.00415   0.000787
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       4/49     11.1G   0.09367   0.05966   0.08112        67       640: 100% 17/17 [00:13<00:00,  1.22it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 3/3 [00:00<00:00,  3.71it/s]
#                  all         50        300      0.452     0.0276   0.000487   9.76e-05
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       5/49     11.1G   0.09553   0.05917   0.08058       102       640: 100% 17/17 [00:14<00:00,  1.21it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 3/3 [00:00<00:00,  3.92it/s]
#                  all         50        300      0.558       0.02    0.00318    0.00106
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       6/49     11.1G   0.08559   0.06501   0.08055        69       640: 100% 17/17 [00:14<00:00,  1.20it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 3/3 [00:00<00:00,  3.02it/s]
#                  all         50        300      0.875    0.00587    0.00277   0.000617
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       7/49     11.1G   0.07774   0.07068   0.07974       117       640: 100% 17/17 [00:14<00:00,  1.20it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 3/3 [00:00<00:00,  3.30it/s]
#                  all         50        300     0.0219      0.452     0.0695     0.0333
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       8/49     11.1G   0.07407   0.06558   0.07898        96       640: 100% 17/17 [00:14<00:00,  1.20it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 3/3 [00:00<00:00,  3.46it/s]
#                  all         50        300      0.522      0.145      0.102     0.0432
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       9/49     11.1G    0.0683   0.06351   0.07854       125       640: 100% 17/17 [00:14<00:00,  1.20it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 3/3 [00:00<00:00,  3.66it/s]
#                  all         50        300      0.208      0.152     0.0503     0.0173
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      10/49     11.1G   0.06265   0.06598   0.07826       105       640: 100% 17/17 [00:14<00:00,  1.20it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 3/3 [00:00<00:00,  3.80it/s]
#                  all         50        300      0.135      0.287      0.108     0.0496
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      11/49     11.1G   0.06105   0.06935   0.07768       123       640: 100% 17/17 [00:14<00:00,  1.19it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 3/3 [00:00<00:00,  3.57it/s]
#                  all         50        300      0.207      0.275     0.0899     0.0215
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      12/49     11.1G   0.05619   0.06219    0.0771       100       640: 100% 17/17 [00:14<00:00,  1.19it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 3/3 [00:00<00:00,  3.71it/s]
#                  all         50        300     0.0857      0.442      0.107     0.0383
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      13/49     11.1G   0.04987   0.06227   0.07575       106       640: 100% 17/17 [00:14<00:00,  1.19it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 3/3 [00:00<00:00,  3.81it/s]
#                  all         50        300      0.155      0.502      0.144     0.0562
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      14/49     11.1G   0.04794    0.0603   0.07582       115       640: 100% 17/17 [00:14<00:00,  1.19it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 3/3 [00:00<00:00,  3.81it/s]
#                  all         50        300      0.144       0.54       0.15     0.0736
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      15/49     11.1G   0.04332   0.06232   0.07477       116       640: 100% 17/17 [00:14<00:00,  1.19it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 3/3 [00:00<00:00,  3.86it/s]
#                  all         50        300      0.214      0.523      0.147     0.0812
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      16/49     11.1G   0.04434   0.05774   0.07374       118       640: 100% 17/17 [00:14<00:00,  1.19it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 3/3 [00:00<00:00,  3.92it/s]
#                  all         50        300      0.219      0.629       0.16      0.075
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      17/49     11.1G   0.04237   0.05945   0.07355       100       640: 100% 17/17 [00:14<00:00,  1.19it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 3/3 [00:00<00:00,  3.98it/s]
#                  all         50        300       0.23      0.632      0.164      0.071
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      18/49     11.1G   0.04088   0.05696   0.07239       109       640: 100% 17/17 [00:14<00:00,  1.18it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 3/3 [00:00<00:00,  3.95it/s]
#                  all         50        300      0.471      0.411      0.208      0.112
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      19/49     11.1G   0.04187   0.06148   0.07208        88       640: 100% 17/17 [00:14<00:00,  1.19it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 3/3 [00:00<00:00,  3.94it/s]
#                  all         50        300      0.289      0.589      0.211      0.113
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      20/49     11.1G   0.03746    0.0575   0.07083        99       640: 100% 17/17 [00:14<00:00,  1.19it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 3/3 [00:00<00:00,  3.93it/s]
#                  all         50        300      0.469      0.503       0.22      0.124
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      21/49     11.1G    0.0404   0.05602   0.07025        93       640: 100% 17/17 [00:14<00:00,  1.19it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 3/3 [00:00<00:00,  4.01it/s]
#                  all         50        300      0.252      0.629      0.241      0.109
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      22/49     11.1G   0.03964   0.05957   0.07028        95       640: 100% 17/17 [00:14<00:00,  1.19it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 3/3 [00:00<00:00,  4.02it/s]
#                  all         50        300      0.407      0.548      0.256      0.113
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      23/49     11.1G   0.04121   0.05753   0.07017       108       640: 100% 17/17 [00:14<00:00,  1.18it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 3/3 [00:00<00:00,  4.06it/s]
#                  all         50        300      0.449      0.459      0.246      0.142
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      24/49     11.1G   0.03659   0.05669   0.06932       110       640: 100% 17/17 [00:14<00:00,  1.19it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 3/3 [00:00<00:00,  4.03it/s]
#                  all         50        300      0.485      0.448      0.273      0.148
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      25/49     11.1G    0.0351   0.05506   0.06947       105       640: 100% 17/17 [00:14<00:00,  1.18it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 3/3 [00:00<00:00,  4.04it/s]
#                  all         50        300      0.388      0.538      0.274      0.146
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      26/49     11.1G   0.03591   0.05193   0.06937        87       640: 100% 17/17 [00:14<00:00,  1.18it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 3/3 [00:00<00:00,  4.04it/s]
#                  all         50        300      0.451      0.502      0.297      0.166
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      27/49     11.1G    0.0344   0.05617   0.06869       120       640: 100% 17/17 [00:14<00:00,  1.18it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 3/3 [00:00<00:00,  4.03it/s]
#                  all         50        300       0.42      0.533      0.311      0.163
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      28/49     11.1G    0.0345   0.05664   0.06905       110       640: 100% 17/17 [00:14<00:00,  1.18it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 3/3 [00:00<00:00,  4.14it/s]
#                  all         50        300      0.465      0.477      0.315      0.185
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      29/49     11.1G   0.03479   0.05402   0.06843        73       640: 100% 17/17 [00:14<00:00,  1.19it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 3/3 [00:00<00:00,  4.08it/s]
#                  all         50        300      0.429      0.517      0.317      0.173
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      30/49     11.1G   0.03333   0.05343   0.06825        99       640: 100% 17/17 [00:14<00:00,  1.18it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 3/3 [00:00<00:00,  4.01it/s]
#                  all         50        300       0.43      0.527      0.338      0.182
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      31/49     11.1G   0.03348   0.05323   0.06805       101       640: 100% 17/17 [00:14<00:00,  1.18it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 3/3 [00:00<00:00,  4.11it/s]
#                  all         50        300       0.45      0.506      0.342      0.196
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      32/49     11.1G   0.03057   0.05307   0.06819       126       640: 100% 17/17 [00:14<00:00,  1.18it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 3/3 [00:00<00:00,  4.09it/s]
#                  all         50        300      0.488      0.401      0.353        0.2
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      33/49     11.1G   0.03136   0.05432   0.06762       102       640: 100% 17/17 [00:14<00:00,  1.18it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 3/3 [00:00<00:00,  4.07it/s]
#                  all         50        300      0.508      0.384      0.373       0.21
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      34/49     11.1G   0.03042   0.05217   0.06717        98       640: 100% 17/17 [00:14<00:00,  1.19it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 3/3 [00:00<00:00,  4.12it/s]
#                  all         50        300      0.531      0.362      0.384      0.222
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      35/49     11.1G   0.03057   0.05052   0.06612       108       640: 100% 17/17 [00:14<00:00,  1.18it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 3/3 [00:00<00:00,  4.12it/s]
#                  all         50        300      0.511      0.386      0.381      0.213
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      36/49     11.1G   0.03151   0.05492   0.06619       102       640: 100% 17/17 [00:14<00:00,  1.18it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 3/3 [00:00<00:00,  4.14it/s]
#                  all         50        300      0.409      0.556      0.389      0.228
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      37/49     11.1G   0.02895   0.05193   0.06608        95       640: 100% 17/17 [00:14<00:00,  1.19it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 3/3 [00:00<00:00,  4.13it/s]
#                  all         50        300      0.426      0.573      0.391      0.223
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      38/49     11.1G   0.02822   0.05099   0.06551       103       640: 100% 17/17 [00:14<00:00,  1.18it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 3/3 [00:00<00:00,  4.16it/s]
#                  all         50        300      0.395       0.61      0.385      0.221
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      39/49     11.1G   0.02832   0.05213   0.06583        72       640: 100% 17/17 [00:14<00:00,  1.18it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 3/3 [00:00<00:00,  4.17it/s]
#                  all         50        300      0.348      0.705      0.389      0.224
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      40/49     11.1G   0.02769   0.05158   0.06591       110       640: 100% 17/17 [00:14<00:00,  1.18it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 3/3 [00:00<00:00,  4.12it/s]
#                  all         50        300      0.353      0.686       0.39      0.226
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      41/49     11.1G   0.02786   0.04925   0.06579       121       640: 100% 17/17 [00:14<00:00,  1.15it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 3/3 [00:00<00:00,  4.16it/s]
#                  all         50        300      0.361      0.647      0.404      0.234
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      42/49     11.1G   0.02802   0.05005   0.06513       106       640: 100% 17/17 [00:14<00:00,  1.18it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 3/3 [00:00<00:00,  4.16it/s]
#                  all         50        300       0.37      0.636      0.414      0.236
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      43/49     11.1G   0.02704   0.04798   0.06566       104       640: 100% 17/17 [00:14<00:00,  1.18it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 3/3 [00:00<00:00,  4.02it/s]
#                  all         50        300      0.433      0.474      0.417      0.239
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      44/49     11.1G   0.02729   0.04948   0.06488       103       640: 100% 17/17 [00:14<00:00,  1.18it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 3/3 [00:00<00:00,  4.13it/s]
#                  all         50        300      0.327      0.663      0.421      0.245
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      45/49     11.1G   0.02693    0.0474   0.06469        80       640: 100% 17/17 [00:14<00:00,  1.19it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 3/3 [00:00<00:00,  4.15it/s]
#                  all         50        300      0.331      0.691      0.425      0.247
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      46/49     11.1G    0.0268    0.0482   0.06511        91       640: 100% 17/17 [00:14<00:00,  1.18it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 3/3 [00:00<00:00,  4.20it/s]
#                  all         50        300      0.334      0.668       0.43      0.248
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      47/49     11.1G   0.02634   0.04802   0.06508       123       640: 100% 17/17 [00:14<00:00,  1.19it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 3/3 [00:00<00:00,  4.13it/s]
#                  all         50        300      0.338      0.657      0.425      0.244
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      48/49     11.1G   0.02577   0.04655    0.0649        87       640: 100% 17/17 [00:14<00:00,  1.18it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 3/3 [00:00<00:00,  4.20it/s]
#                  all         50        300      0.369      0.659      0.425      0.242
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      49/49     11.1G   0.02616   0.04661   0.06442       119       640: 100% 17/17 [00:14<00:00,  1.18it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 3/3 [00:00<00:00,  4.22it/s]
#                  all         50        300       0.37      0.651      0.428      0.243
#
# 50 epochs completed in 0.270 hours.
# Optimizer stripped from runs/train/exp3/weights/last.pt, 173.4MB
# Optimizer stripped from runs/train/exp3/weights/best.pt, 173.4MB
#
# Validating runs/train/exp3/weights/best.pt...
# Fusing layers...
# Model Summary: 444 layers, 86382013 parameters, 0 gradients
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 3/3 [00:01<00:00,  2.23it/s]
#                  all         50        300      0.333      0.679       0.43      0.248
#                    2         50         55      0.856      0.982      0.988      0.631
#                    A         50          7      0.182      0.104      0.079     0.0535
#                    H         50         11      0.193      0.636      0.197      0.126
#                    N         50         15        0.1      0.867       0.46      0.289
#                    3         50          6      0.346          1      0.719      0.353
#                    L         50         10       0.14        0.9      0.593      0.273
#                    S         50          4      0.152          1      0.495      0.258
#                    G         50         10      0.176          1      0.571      0.301
#                    P         50          7          1          0      0.545      0.255
#                    6         50          7          0          0      0.196     0.0992
#                    T         50         11       0.29      0.779      0.274      0.177
#                    J         50          9      0.554          1      0.884      0.519
#                    F         50          6      0.158      0.333      0.182     0.0902
#                    R         50          6      0.142      0.966      0.401      0.291
#                    Q         50          9      0.134          1      0.776      0.543
#                    D         50          8      0.176          1      0.245      0.156
#                    5         50          2      0.131          1      0.133     0.0615
#                    B         50          8          1          0      0.254      0.161
#                    7         50          8          1          0      0.227      0.102
#                    8         50          3      0.173          1      0.736      0.339
#                    E         50         10     0.0994          1      0.583      0.361
#                    9         50          1     0.0471          1     0.0585     0.0234
#                    Y         50         12      0.134      0.583      0.137      0.095
#                    4         50          9          1          0      0.569      0.262
#                    W         50          6      0.203      0.667      0.482      0.318
#                    K         50         13      0.162       0.79      0.196      0.128
#                    U         50         11      0.243      0.909      0.579      0.337
#                    X         50          8     0.0871      0.625      0.273      0.144
#                    V         50          9          1      0.187      0.694      0.399
#                    C         50          7      0.146      0.901      0.291       0.19
#                    M         50         12      0.309      0.833      0.507      0.343
# Results saved to runs/train/exp3

# %% [markdown]
# ## Inference

# %%
# !python detect.py --img 300 --source /content/convertor/fold0/images/train2017 --weights ./runs/train/exp3/weights/best.pt --conf-thres 0.2
# Out:
# detect: weights=['./runs/train/exp3/weights/best.pt'], source=/content/convertor/fold0/images/train2017, data=data/coco128.yaml, imgsz=[300, 300], conf_thres=0.2, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-11-g63ddb6f torch 1.10.0+cu111 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model Summary: 444 layers, 86382013 parameters, 0 gradients
# WARNING: --img-size [300, 300] must be multiple of max stride 32, updating to [320, 320]
# image 1/200 /content/convertor/fold0/images/train2017/2AHN3L.png: 96x320 1 2, Done. (0.034s)
# image 2/200 /content/convertor/fold0/images/train2017/2AHSGS.png: 96x320 1 2, 1 S, Done. (0.025s)
# image 3/200 /content/convertor/fold0/images/train2017/2ARQLL.png: 96x320 1 2, 1 G, 1 Q, Done. (0.024s)
# image 4/200 /content/convertor/fold0/images/train2017/2AU35Q.png: 96x320 1 2, 1 G, 1 Q, Done. (0.020s)
# image 5/200 /content/convertor/fold0/images/train2017/2B7NTP.png: 96x320 1 2, Done. (0.020s)
# image 6/200 /content/convertor/fold0/images/train2017/2B8E9E.png: 96x320 1 2, Done. (0.021s)
# image 7/200 /content/convertor/fold0/images/train2017/2B8SY5.png: 96x320 1 2, Done. (0.023s)
# image 8/200 /content/convertor/fold0/images/train2017/2B9HLN.png: 96x320 1 2, Done. (0.020s)
# image 9/200 /content/convertor/fold0/images/train2017/2B9T34.png: 96x320 2 2s, 2 Ss, Done. (0.020s)
# image 10/200 /content/convertor/fold0/images/train2017/2BGAW4.png: 96x320 1 2, Done. (0.020s)
# image 11/200 /content/convertor/fold0/images/train2017/2BH2SA.png: 96x320 3 2s, Done. (0.020s)
# image 12/200 /content/convertor/fold0/images/train2017/2BLJX8.JPG: 96x320 1 2, Done. (0.016s)
# image 13/200 /content/convertor/fold0/images/train2017/2BNRA4.png: 96x320 1 2, Done. (0.016s)
# image 14/200 /content/convertor/fold0/images/train2017/2BNVAJ.png: 96x320 1 2, Done. (0.016s)
# image 15/200 /content/convertor/fold0/images/train2017/2BRKRV.png: 96x320 1 2, Done. (0.018s)
# image 16/200 /content/convertor/fold0/images/train2017/2BSFAL.png: 96x320 1 2, 1 S, Done. (0.016s)
# image 17/200 /content/convertor/fold0/images/train2017/2C3B87.png: 96x320 1 2, 1 S, Done. (0.016s)
# image 18/200 /content/convertor/fold0/images/train2017/2C5T8F.png: 96x320 1 2, 1 S, Done. (0.016s)
# image 19/200 /content/convertor/fold0/images/train2017/2C6KM9.png: 96x320 1 2, Done. (0.016s)
# image 20/200 /content/convertor/fold0/images/train2017/2CBGW4.JPG: 96x320 1 2, 1 G, 1 Q, Done. (0.017s)
# image 21/200 /content/convertor/fold0/images/train2017/2CFJ7L.png: 96x320 1 2, 1 S, Done. (0.016s)
# image 22/200 /content/convertor/fold0/images/train2017/2CQ8EF.JPG: 96x320 1 2, 1 G, 1 Q, Done. (0.017s)
# image 23/200 /content/convertor/fold0/images/train2017/2CQN8E.png: 96x320 1 2, 1 S, 2 Gs, 1 Q, Done. (0.019s)
# image 24/200 /content/convertor/fold0/images/train2017/2CT6FT.png: 96x320 1 2, Done. (0.016s)
# image 25/200 /content/convertor/fold0/images/train2017/2CTMNT.png: 96x320 1 2, 1 S, 1 G, 1 Q, Done. (0.019s)
# image 26/200 /content/convertor/fold0/images/train2017/2CXCKM.png: 96x320 1 2, Done. (0.016s)
# image 27/200 /content/convertor/fold0/images/train2017/2D6N96.png: 96x320 1 2, Done. (0.016s)
# image 28/200 /content/convertor/fold0/images/train2017/2D8TDL.png: 96x320 2 2s, 1 S, Done. (0.016s)
# image 29/200 /content/convertor/fold0/images/train2017/2DDERS.png: 96x320 1 2, 1 S, Done. (0.016s)
# image 30/200 /content/convertor/fold0/images/train2017/2DFU3L.png: 96x320 1 2, 1 S, Done. (0.016s)
# image 31/200 /content/convertor/fold0/images/train2017/2DGKPE.png: 96x320 2 2s, Done. (0.016s)
# image 32/200 /content/convertor/fold0/images/train2017/2DJ9L3.png: 96x320 1 2, 1 3, 1 S, Done. (0.016s)
# image 33/200 /content/convertor/fold0/images/train2017/2DK2EY.png: 96x320 2 2s, Done. (0.016s)
# image 34/200 /content/convertor/fold0/images/train2017/2DKA34.png: 96x320 1 2, 1 S, Done. (0.016s)
# image 35/200 /content/convertor/fold0/images/train2017/2DS285.png: 96x320 2 2s, 1 S, Done. (0.016s)
# image 36/200 /content/convertor/fold0/images/train2017/2E9X2S.PNG: 96x320 2 2s, 2 Ss, Done. (0.016s)
# image 37/200 /content/convertor/fold0/images/train2017/2EEGRW.png: 96x320 1 2, 1 G, 1 Q, Done. (0.016s)
# image 38/200 /content/convertor/fold0/images/train2017/2EGFJX.png: 96x320 1 2, 1 G, Done. (0.016s)
# image 39/200 /content/convertor/fold0/images/train2017/2EM8XY.png: 96x320 1 2, Done. (0.016s)
# image 40/200 /content/convertor/fold0/images/train2017/2ENNE8.png: 96x320 1 2, Done. (0.016s)
# image 41/200 /content/convertor/fold0/images/train2017/2EPQC9.png: 96x320 1 2, 1 G, 2 Qs, Done. (0.016s)
# image 42/200 /content/convertor/fold0/images/train2017/2EPS4S.png: 96x320 1 2, 1 3, 1 S, Done. (0.017s)
# image 43/200 /content/convertor/fold0/images/train2017/2EVMER.png: 96x320 1 2, Done. (0.019s)
# image 44/200 /content/convertor/fold0/images/train2017/2EYXAC.PNG: 96x320 1 2, Done. (0.016s)
# image 45/200 /content/convertor/fold0/images/train2017/2F34YY.png: 96x320 1 2, Done. (0.016s)
# image 46/200 /content/convertor/fold0/images/train2017/2F876E.png: 96x320 2 2s, Done. (0.017s)
# image 47/200 /content/convertor/fold0/images/train2017/2F8SUV.png: 96x320 1 2, 1 S, Done. (0.016s)
# image 48/200 /content/convertor/fold0/images/train2017/2FB897.png: 96x320 1 2, Done. (0.018s)
# image 49/200 /content/convertor/fold0/images/train2017/2FLYLN.png: 96x320 1 2, Done. (0.016s)
# image 50/200 /content/convertor/fold0/images/train2017/2FMAPL.png: 96x320 1 2, Done. (0.016s)
# image 51/200 /content/convertor/fold0/images/train2017/2FNJE7.png: 96x320 1 2, Done. (0.016s)
# image 52/200 /content/convertor/fold0/images/train2017/2FPSUU.png: 96x320 1 2, Done. (0.017s)
# image 53/200 /content/convertor/fold0/images/train2017/2FQRE8.png: 96x320 1 2, Done. (0.016s)
# image 54/200 /content/convertor/fold0/images/train2017/2FVDAD.png: 96x320 1 2, Done. (0.016s)
# image 55/200 /content/convertor/fold0/images/train2017/2G2TLA.png: 96x320 2 2s, 1 S, Done. (0.016s)
# image 56/200 /content/convertor/fold0/images/train2017/2G83VG.png: 96x320 1 2, 1 S, 1 G, Done. (0.017s)
# image 57/200 /content/convertor/fold0/images/train2017/2GGMDD.png: 96x320 1 2, 1 S, Done. (0.021s)
# image 58/200 /content/convertor/fold0/images/train2017/2GHXEE.png: 96x320 2 2s, Done. (0.016s)
# image 59/200 /content/convertor/fold0/images/train2017/2GKELA.png: 96x320 1 2, 1 S, 1 Q, Done. (0.016s)
# image 60/200 /content/convertor/fold0/images/train2017/2GKJ2H.png: 96x320 2 2s, 1 S, 1 G, 1 Q, Done. (0.016s)
# image 61/200 /content/convertor/fold0/images/train2017/2GMDQ2.png: 96x320 2 2s, 1 S, 1 G, 1 Q, Done. (0.017s)
# image 62/200 /content/convertor/fold0/images/train2017/2GNFN3.png: 96x320 1 2, 1 S, Done. (0.025s)
# image 63/200 /content/convertor/fold0/images/train2017/2GP6HL.PNG: 96x320 1 2, Done. (0.019s)
# image 64/200 /content/convertor/fold0/images/train2017/2GQY26.png: 96x320 3 2s, 1 S, 1 G, 2 Qs, Done. (0.016s)
# image 65/200 /content/convertor/fold0/images/train2017/2GWUQR.png: 96x320 1 2, Done. (0.016s)
# image 66/200 /content/convertor/fold0/images/train2017/2H3GED.png: 96x320 1 2, 1 G, Done. (0.019s)
# image 67/200 /content/convertor/fold0/images/train2017/2H9R9N.png: 96x320 1 2, Done. (0.016s)
# image 68/200 /content/convertor/fold0/images/train2017/2HCY9P.png: 96x320 1 2, 1 G, 1 Q, Done. (0.016s)
# image 69/200 /content/convertor/fold0/images/train2017/2HG9R9.png: 96x320 1 2, 1 G, Done. (0.016s)
# image 70/200 /content/convertor/fold0/images/train2017/2HGNQS.png: 96x320 1 2, 1 S, 1 G, 2 Qs, Done. (0.019s)
# image 71/200 /content/convertor/fold0/images/train2017/2HHXAV.png: 96x320 1 2, Done. (0.016s)
# image 72/200 /content/convertor/fold0/images/train2017/2HQJ4P.png: 96x320 2 2s, 1 Q, Done. (0.017s)
# image 73/200 /content/convertor/fold0/images/train2017/2HRD9X.png: 96x320 1 2, Done. (0.016s)
# image 74/200 /content/convertor/fold0/images/train2017/2HT77K.png: 96x320 2 2s, Done. (0.017s)
# image 75/200 /content/convertor/fold0/images/train2017/2HUKEE.png: 96x320 1 2, Done. (0.018s)
# image 76/200 /content/convertor/fold0/images/train2017/2HW4FL.PNG: 96x320 1 2, Done. (0.017s)
# image 77/200 /content/convertor/fold0/images/train2017/2J9WWS.png: 96x320 1 2, Done. (0.016s)
# image 78/200 /content/convertor/fold0/images/train2017/2JACMJ.png: 96x320 1 2, Done. (0.017s)
# image 79/200 /content/convertor/fold0/images/train2017/2JECYS.png: 96x320 1 S, Done. (0.017s)
# image 80/200 /content/convertor/fold0/images/train2017/2JFNRV.png: 96x320 1 2, Done. (0.016s)
# image 81/200 /content/convertor/fold0/images/train2017/2JKEYS.png: 96x320 1 2, Done. (0.016s)
# image 82/200 /content/convertor/fold0/images/train2017/2JKRQR.png: 96x320 1 2, Done. (0.016s)
# image 83/200 /content/convertor/fold0/images/train2017/2JLJKQ.png: 96x320 1 2, Done. (0.016s)
# image 84/200 /content/convertor/fold0/images/train2017/2JR5NY.png: 96x320 1 2, Done. (0.016s)
# image 85/200 /content/convertor/fold0/images/train2017/2JRDA3.png: 96x320 1 2, Done. (0.019s)
# image 86/200 /content/convertor/fold0/images/train2017/2JRJLU.png: 96x320 1 2, Done. (0.016s)
# image 87/200 /content/convertor/fold0/images/train2017/2K45CR.png: 96x320 1 2, 1 S, Done. (0.016s)
# image 88/200 /content/convertor/fold0/images/train2017/2KCGDL.png: 96x320 1 2, Done. (0.016s)
# image 89/200 /content/convertor/fold0/images/train2017/2KELN5.png: 96x320 1 2, 1 S, Done. (0.019s)
# image 90/200 /content/convertor/fold0/images/train2017/2KEUBP.PNG: 96x320 1 2, Done. (0.016s)
# image 91/200 /content/convertor/fold0/images/train2017/2KGQFL.png: 96x320 1 2, 1 G, 1 Q, Done. (0.017s)
# image 92/200 /content/convertor/fold0/images/train2017/2KJ5RC.png: 96x320 1 2, Done. (0.016s)
# image 93/200 /content/convertor/fold0/images/train2017/2KLS6D.png: 96x320 1 2, Done. (0.016s)
# image 94/200 /content/convertor/fold0/images/train2017/2KTFMG.png: 96x320 1 2, 1 G, Done. (0.016s)
# image 95/200 /content/convertor/fold0/images/train2017/2KX5UV.png: 96x320 1 2, Done. (0.016s)
# image 96/200 /content/convertor/fold0/images/train2017/2KYR7B.png: 96x320 1 2, Done. (0.016s)
# image 97/200 /content/convertor/fold0/images/train2017/2L3YNL.png: 96x320 1 2, Done. (0.016s)
# image 98/200 /content/convertor/fold0/images/train2017/2L4PCU.png: 96x320 1 2, 1 S, Done. (0.016s)
# image 99/200 /content/convertor/fold0/images/train2017/2L5F9A.png: 96x320 1 2, Done. (0.016s)
# image 100/200 /content/convertor/fold0/images/train2017/2LFLBT.png: 96x320 1 2, Done. (0.019s)
# image 101/200 /content/convertor/fold0/images/train2017/2LFMQ6.png: 96x320 1 2, Done. (0.016s)
# image 102/200 /content/convertor/fold0/images/train2017/2LHQ53.png: 96x320 1 2, 2 Ss, 1 G, 1 Q, Done. (0.016s)
# image 103/200 /content/convertor/fold0/images/train2017/2LLHN6.png: 96x320 1 2, Done. (0.016s)
# image 104/200 /content/convertor/fold0/images/train2017/2LMJQ5.png: 96x320 1 2, 1 S, 1 Q, Done. (0.016s)
# image 105/200 /content/convertor/fold0/images/train2017/2M2YY3.png: 96x320 2 2s, Done. (0.016s)
# image 106/200 /content/convertor/fold0/images/train2017/2M3MAB.png: 96x320 1 2, Done. (0.016s)
# image 107/200 /content/convertor/fold0/images/train2017/2MG22N.png: 96x320 3 2s, Done. (0.022s)
# image 108/200 /content/convertor/fold0/images/train2017/2MLEKN.png: 96x320 1 2, Done. (0.016s)
# image 109/200 /content/convertor/fold0/images/train2017/2MNRYW.png: 96x320 1 2, Done. (0.017s)
# image 110/200 /content/convertor/fold0/images/train2017/2MQ6WQ.png: 96x320 1 2, 1 G, 1 Q, Done. (0.016s)
# image 111/200 /content/convertor/fold0/images/train2017/2N56A4.png: 96x320 1 2, 1 S, Done. (0.016s)
# image 112/200 /content/convertor/fold0/images/train2017/2N5KP8.png: 96x320 1 2, Done. (0.016s)
# image 113/200 /content/convertor/fold0/images/train2017/2NCV28.png: 96x320 2 2s, 1 S, Done. (0.016s)
# image 114/200 /content/convertor/fold0/images/train2017/2NELJU.png: 96x320 1 2, Done. (0.016s)
# image 115/200 /content/convertor/fold0/images/train2017/2NJNBG.png: 96x320 1 2, 1 G, Done. (0.018s)
# image 116/200 /content/convertor/fold0/images/train2017/2NLRPQ.png: 96x320 1 2, 1 G, 1 Q, Done. (0.016s)
# image 117/200 /content/convertor/fold0/images/train2017/2NNDAV.png: 96x320 1 2, Done. (0.016s)
# image 118/200 /content/convertor/fold0/images/train2017/2NNRKE.png: 96x320 1 2, Done. (0.018s)
# image 119/200 /content/convertor/fold0/images/train2017/2NPACD.png: 96x320 1 2, 1 S, 1 Q, Done. (0.016s)
# image 120/200 /content/convertor/fold0/images/train2017/2NSSBG.png: 96x320 1 2, 1 Q, Done. (0.016s)
# image 121/200 /content/convertor/fold0/images/train2017/2NUP2P.png: 96x320 2 2s, Done. (0.016s)
# image 122/200 /content/convertor/fold0/images/train2017/2NY9GH.png: 96x320 1 2, Done. (0.016s)
# image 123/200 /content/convertor/fold0/images/train2017/2NYG8H.png: 96x320 1 2, Done. (0.016s)
# image 124/200 /content/convertor/fold0/images/train2017/2PAXHG.png: 96x320 1 2, 1 G, 1 Q, Done. (0.016s)
# image 125/200 /content/convertor/fold0/images/train2017/2PHP49.png: 96x320 1 2, Done. (0.017s)
# image 126/200 /content/convertor/fold0/images/train2017/2PLBUS.png: 96x320 1 2, 1 S, Done. (0.016s)
# image 127/200 /content/convertor/fold0/images/train2017/2PM8QV.png: 96x320 1 2, Done. (0.016s)
# image 128/200 /content/convertor/fold0/images/train2017/2QE9WG.png: 96x320 1 2, Done. (0.016s)
# image 129/200 /content/convertor/fold0/images/train2017/2QF783.png: 96x320 1 2, 2 Ss, Done. (0.016s)
# image 130/200 /content/convertor/fold0/images/train2017/2QR4AT.png: 96x320 1 2, Done. (0.016s)
# image 131/200 /content/convertor/fold0/images/train2017/2QSFXT.png: 96x320 1 2, Done. (0.018s)
# image 132/200 /content/convertor/fold0/images/train2017/2QXSH9.png: 96x320 1 2, 1 S, 1 Q, Done. (0.016s)
# image 133/200 /content/convertor/fold0/images/train2017/2RJQ5G.png: 96x320 1 2, 1 S, 2 Gs, 1 Q, Done. (0.017s)
# image 134/200 /content/convertor/fold0/images/train2017/2RT3JA.png: 96x320 1 2, Done. (0.016s)
# image 135/200 /content/convertor/fold0/images/train2017/2RWQ9U.png: 96x320 1 2, Done. (0.016s)
# image 136/200 /content/convertor/fold0/images/train2017/2RXBK4.png: 96x320 1 2, Done. (0.017s)
# image 137/200 /content/convertor/fold0/images/train2017/2SB5KR.png: 96x320 1 2, 2 Ss, Done. (0.016s)
# image 138/200 /content/convertor/fold0/images/train2017/2SCE43.png: 96x320 1 2, Done. (0.016s)
# image 139/200 /content/convertor/fold0/images/train2017/2SF5EQ.png: 96x320 1 2, 1 Q, Done. (0.016s)
# image 140/200 /content/convertor/fold0/images/train2017/2SJEQ7.PNG: 96x320 1 2, Done. (0.016s)
# image 141/200 /content/convertor/fold0/images/train2017/2SKEFA.png: 96x320 1 2, Done. (0.017s)
# image 142/200 /content/convertor/fold0/images/train2017/2SQL4F.png: 96x320 1 2, 1 S, 1 G, 1 Q, Done. (0.019s)
# image 143/200 /content/convertor/fold0/images/train2017/2STKMN.png: 96x320 1 2, Done. (0.016s)
# image 144/200 /content/convertor/fold0/images/train2017/2STN2F.png: 96x320 2 2s, Done. (0.016s)
# image 145/200 /content/convertor/fold0/images/train2017/2SUQ7R.png: 96x320 1 2, Done. (0.016s)
# image 146/200 /content/convertor/fold0/images/train2017/2SWKXX.png: 96x320 1 2, 1 S, Done. (0.019s)
# image 147/200 /content/convertor/fold0/images/train2017/2TD6AX.png: 96x320 1 2, Done. (0.016s)
# image 148/200 /content/convertor/fold0/images/train2017/2TFFU8.png: 96x320 1 2, 1 S, Done. (0.016s)
# image 149/200 /content/convertor/fold0/images/train2017/2TGTY6.png: 96x320 1 2, 1 G, Done. (0.016s)
# image 150/200 /content/convertor/fold0/images/train2017/2TQ9Y2.png: 96x320 3 2s, 1 G, 1 Q, Done. (0.016s)
# image 151/200 /content/convertor/fold0/images/train2017/2TQC77.JPG: 96x320 1 2, 2 Gs, 1 Q, Done. (0.017s)
# image 152/200 /content/convertor/fold0/images/train2017/2TQT8H.png: 96x320 1 2, 1 S, 1 Q, Done. (0.016s)
# image 153/200 /content/convertor/fold0/images/train2017/2TTGLJ.png: 96x320 1 2, Done. (0.016s)
# image 154/200 /content/convertor/fold0/images/train2017/2TYBUR.png: 96x320 1 2, Done. (0.016s)
# image 155/200 /content/convertor/fold0/images/train2017/2TYNR5.png: 96x320 1 2, 1 S, Done. (0.016s)
# image 156/200 /content/convertor/fold0/images/train2017/2U236J.png: 96x320 2 2s, 1 S, Done. (0.016s)
# image 157/200 /content/convertor/fold0/images/train2017/2U2WYC.PNG: 96x320 1 2, 1 S, 1 G, 1 Q, Done. (0.016s)
# image 158/200 /content/convertor/fold0/images/train2017/2U3FDD.png: 96x320 1 2, Done. (0.022s)
# image 159/200 /content/convertor/fold0/images/train2017/2UB7NW.png: 96x320 1 2, Done. (0.018s)
# image 160/200 /content/convertor/fold0/images/train2017/2UBPCE.png: 96x320 1 2, 1 S, Done. (0.017s)
# image 161/200 /content/convertor/fold0/images/train2017/2UD4NQ.png: 96x320 1 2, 1 G, 1 Q, Done. (0.017s)
# image 162/200 /content/convertor/fold0/images/train2017/2UE9S8.png: 96x320 1 2, 1 S, Done. (0.016s)
# image 163/200 /content/convertor/fold0/images/train2017/2UGD7M.JPG: 96x320 1 2, 1 S, Done. (0.016s)
# image 164/200 /content/convertor/fold0/images/train2017/2UGR3T.png: 96x320 1 2, 1 G, 1 Q, Done. (0.016s)
# image 165/200 /content/convertor/fold0/images/train2017/2UKFQU.png: 96x320 1 2, 1 S, 1 Q, Done. (0.016s)
# image 166/200 /content/convertor/fold0/images/train2017/2UMBFN.png: 96x320 1 2, Done. (0.016s)
# image 167/200 /content/convertor/fold0/images/train2017/2UNTBK.png: 96x320 1 2, Done. (0.016s)
# image 168/200 /content/convertor/fold0/images/train2017/2UP4G2.png: 96x320 2 2s, Done. (0.016s)
# image 169/200 /content/convertor/fold0/images/train2017/2UQTV7.png: 96x320 1 2, 1 S, 1 G, 1 Q, Done. (0.016s)
# image 170/200 /content/convertor/fold0/images/train2017/2USJ49.png: 96x320 1 2, 1 S, Done. (0.017s)
# image 171/200 /content/convertor/fold0/images/train2017/2UURLA.png: 96x320 1 2, Done. (0.016s)
# image 172/200 /content/convertor/fold0/images/train2017/2UVJGV.png: 96x320 1 2, 1 S, Done. (0.016s)
# image 173/200 /content/convertor/fold0/images/train2017/2UYSVQ.png: 96x320 1 2, 1 G, 1 Q, Done. (0.016s)
# image 174/200 /content/convertor/fold0/images/train2017/2V5CYP.png: 96x320 1 2, 1 S, Done. (0.016s)
# image 175/200 /content/convertor/fold0/images/train2017/2VKV3S.png: 96x320 1 2, 1 S, Done. (0.016s)
# image 176/200 /content/convertor/fold0/images/train2017/2VSQGH.png: 96x320 1 2, 2 Ss, 1 G, 1 Q, Done. (0.020s)
# image 177/200 /content/convertor/fold0/images/train2017/2VUATF.png: 96x320 1 2, Done. (0.017s)
# image 178/200 /content/convertor/fold0/images/train2017/2W45MD.png: 96x320 1 2, Done. (0.016s)
# image 179/200 /content/convertor/fold0/images/train2017/2WJ9BL.png: 96x320 1 2, Done. (0.019s)
# image 180/200 /content/convertor/fold0/images/train2017/2WJNSE.png: 96x320 1 2, 1 S, Done. (0.016s)
# image 181/200 /content/convertor/fold0/images/train2017/2WLGAD.png: 96x320 1 2, 1 G, 1 Q, Done. (0.017s)
# image 182/200 /content/convertor/fold0/images/train2017/2WRNLJ.png: 96x320 1 2, Done. (0.016s)
# image 183/200 /content/convertor/fold0/images/train2017/2WWUCL.png: 96x320 1 2, 1 S, 1 Q, Done. (0.017s)
# image 184/200 /content/convertor/fold0/images/train2017/2X2RL8.png: 96x320 2 2s, 1 S, Done. (0.017s)
# image 185/200 /content/convertor/fold0/images/train2017/2X9DBN.png: 96x320 1 2, Done. (0.016s)
# image 186/200 /content/convertor/fold0/images/train2017/2XDE6C.png: 96x320 1 2, Done. (0.016s)
# image 187/200 /content/convertor/fold0/images/train2017/2XH8TQ.png: 96x320 1 2, 1 G, 1 Q, Done. (0.016s)
# image 188/200 /content/convertor/fold0/images/train2017/2XLH4E.png: 96x320 3 2s, Done. (0.016s)
# image 189/200 /content/convertor/fold0/images/train2017/2XP4C8.png: 96x320 1 2, 1 S, Done. (0.016s)
# image 190/200 /content/convertor/fold0/images/train2017/2XQHVX.png: 96x320 1 2, 1 G, 1 Q, Done. (0.016s)
# image 191/200 /content/convertor/fold0/images/train2017/2XQTFA.png: 96x320 1 2, 1 G, 1 Q, Done. (0.020s)
# image 192/200 /content/convertor/fold0/images/train2017/2XRYTH.png: 96x320 1 2, Done. (0.016s)
# image 193/200 /content/convertor/fold0/images/train2017/2XVSJ6.png: 96x320 1 2, Done. (0.016s)
# image 194/200 /content/convertor/fold0/images/train2017/2XYB5X.png: 96x320 1 2, Done. (0.016s)
# image 195/200 /content/convertor/fold0/images/train2017/2Y74MJ.png: 96x320 1 2, Done. (0.016s)
# image 196/200 /content/convertor/fold0/images/train2017/2Y9P55.png: 96x320 1 2, 1 S, Done. (0.017s)
# image 197/200 /content/convertor/fold0/images/train2017/2YK9T9.png: 96x320 1 2, Done. (0.016s)
# image 198/200 /content/convertor/fold0/images/train2017/2YM2FU.png: 96x320 3 2s, Done. (0.016s)
# image 199/200 /content/convertor/fold0/images/train2017/2YNT3F.png: 96x320 1 2, Done. (0.018s)
# image 200/200 /content/convertor/fold0/images/train2017/2YQV4Y.png: 96x320 1 2, 1 G, 1 Q, Done. (0.016s)
# Speed: 0.1ms pre-process, 16.8ms inference, 0.9ms NMS per image at shape (1, 3, 320, 320)
# Results saved to runs/detect/exp

# %% [markdown]
# ## Testing

# %%
# !python val.py --data ./data/coco.yml --weights ./runs/train/exp3/weights/best.pt
# Out:
# val: data=./data/coco.yml, weights=['./runs/train/exp3/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-11-g63ddb6f torch 1.10.0+cu111 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model Summary: 444 layers, 86382013 parameters, 0 gradients
# val: Scanning '/content/convertor/fold0/labels/val2017.cache' images and labels... 50 found, 0 missing, 0 empty, 0 corrupt: 100% 50/50 [00:00<?, ?it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 2/2 [00:02<00:00,  1.01s/it]
#                  all         50        300      0.334      0.669       0.43      0.249
#                    2         50         55      0.864      0.982      0.988      0.631
#                    A         50          7      0.126     0.0719      0.079     0.0535
#                    H         50         11      0.201      0.636      0.197      0.126
#                    N         50         15      0.103      0.867       0.46      0.289
#                    3         50          6      0.349          1      0.719      0.353
#                    L         50         10      0.144        0.9      0.593      0.273
#                    S         50          4      0.153          1      0.495      0.258
#                    G         50         10      0.177          1      0.571      0.308
#                    P         50          7          1          0      0.545      0.255
#                    6         50          7          0          0      0.196     0.0992
#                    T         50         11      0.289      0.702      0.265      0.168
#                    J         50          9      0.568          1      0.884      0.519
#                    F         50          6      0.176      0.333      0.182     0.0902
#                    R         50          6      0.126      0.833      0.401       0.29
#                    Q         50          9      0.137          1      0.776      0.543
#                    D         50          8      0.175      0.984      0.245      0.156
#                    5         50          2      0.131          1      0.133     0.0615
#                    B         50          8          1          0      0.254      0.161
#                    7         50          8          1          0      0.227      0.103
#                    8         50          3      0.174          1      0.736      0.339
#                    E         50         10      0.104          1      0.583      0.378
#                    9         50          1      0.053          1     0.0585     0.0234
#                    Y         50         12      0.134      0.583      0.137      0.095
#                    4         50          9          1          0      0.569      0.261
#                    W         50          6      0.207      0.667      0.482      0.318
#                    K         50         13      0.167      0.769      0.195      0.129
#                    U         50         11      0.244      0.909      0.579      0.337
#                    X         50          8     0.0906      0.625      0.274      0.144
#                    V         50          9          1      0.179      0.693      0.408
#                    C         50          7      0.141      0.866      0.291       0.19
#                    M         50         12       0.32      0.833      0.507      0.343
# Speed: 0.1ms pre-process, 19.1ms inference, 4.4ms NMS per image at shape (32, 3, 640, 640)
# Results saved to runs/val/exp3
